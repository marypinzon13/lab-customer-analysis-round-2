# %%
import pandas as pd  # keywords are highlighted in green, other strings in red, etc.
import numpy as np

# %%
ls -l
# Out:
# total 2696
# -rw-r--r--  1 maryramirez  staff       72 Jul 21 23:25 Lab-customer-analysis.2-Mary.ipynb
# -rw-r--r--  1 maryramirez  staff  1373574 Jul 21 23:20 marketing_customer_analysis.xlsx

# %%
#Show the dataframe shape
file1 = pd.read_excel('marketing_customer_analysis.xlsx')
display(file1.head())
display(file1.tail())
file1.shape
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0         0.0  DK49336     Arizona              4809.216960       No
# 1         1.0  KX64629  California              2228.525238       No
# 2         2.0  LZ68649  Washington             14947.917300       No
# 3         3.0  XL78013      Oregon             22332.439460      Yes
# 4         4.0  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
data = file1.copy()

# %%
data.dtypes
# Out:
# Unnamed: 0                              float64
# Customer                                 object
# State                                    object
# Customer Lifetime Value                 float64
# Response                                 object
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# EmploymentStatus                         object
# Gender                                   object
# Income                                  float64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                    float64
# Months Since Last Claim                 float64
# Months Since Policy Inception           float64
# Number of Open Complaints               float64
# Number of Policies                      float64
# Policy Type                              object
# Policy                                   object
# ...

# %%
#Standardize header names.

# %%
column_name_data =data.columns
column_name_data
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
columns = []
for i in range(len(data.columns)):
    columns.append(data.columns[i].lower())
data.columns = columns

data.head(2)
# Out:
#    unnamed: 0 customer       state  customer lifetime value response coverage  \
# 0         0.0  DK49336     Arizona              4809.216960       No    Basic
# 1         1.0  KX64629  California              2228.525238       No    Basic
#
#   education effective to date employmentstatus gender  ...  \
# 0   College        2011-02-18         Employed      M  ...
# 1   College        2011-01-18       Unemployed      F  ...
#
#    number of open complaints number of policies     policy type        policy  \
# 0                        0.0                9.0  Corporate Auto  Corporate L3
# 1                        0.0                1.0   Personal Auto   Personal L3
#
#    renew offer type  sales channel  total claim amount  vehicle class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
#
#   vehicle size vehicle type
# 0      Medsize          NaN
# 1      Medsize          NaN
#
# ...

# %%
#Which columns are numerical? and categorical?

# %%
data.dtypes
# Out:
# unnamed: 0                              float64
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                  float64
# location code                            object
# marital status                           object
# monthly premium auto                    float64
# months since last claim                 float64
# months since policy inception           float64
# number of open complaints               float64
# number of policies                      float64
# policy type                              object
# policy                                   object
# ...

# %%
data.isna().sum()
# Out:
# unnamed: 0                          0
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# ...

# %%
data[data['state'].isna()].head(30)
#, 'response', 'months since last claim', 'number of open complaints',
#          'vehicle class','vehicle size','vehicle type'
# Out:
#      unnamed: 0 customer state  customer lifetime value response  coverage  \
# 5           5.0  HO81102   NaN              4745.181764      NaN     Basic
# 11         11.0  GE63585   NaN              2420.711888      NaN     Basic
# 58         58.0  BR69566   NaN             14019.833140      NaN     Basic
# 62         62.0  UF44021   NaN              2108.493744      NaN     Basic
# 126       126.0  TE60343   NaN              4716.264294      NaN     Basic
# 131       131.0  QK24293   NaN              6265.343299      NaN  Extended
# 155       155.0  JG35886   NaN              4111.888285      NaN   Premium
# 168       168.0  FV22585   NaN              6960.920371      NaN  Extended
# 169       169.0  AU23837   NaN              5010.379310      NaN     Basic
# 190       190.0  VZ18907   NaN             21991.615980      NaN     Basic
# 226       226.0  VK57280   NaN              4727.354548      NaN     Basic
# ...

# %%
data['state'].nunique()
data['state'].value_counts()
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: state, dtype: int64

# %%
data['state'] = data['state'].fillna('Unknown')
len(data[data['state'].isna() == True])
# Out:
# 0

# %%
data.isna().sum()
# Out:
# unnamed: 0                          0
# customer                            0
# state                               0
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# ...

# %%
data['response'].nunique()
data['response'].value_counts()
# Out:
# No     8813
# Yes    1466
# Name: response, dtype: int64

# %%
data['response'] = data['response'].fillna('Unknown')
len(data[data['response'].isna() == True])
# Out:
# 0

# %%
data['response'].nunique()
data['response'].value_counts()
# Out:
# No         8813
# Yes        1466
# Unknown     631
# Name: response, dtype: int64

# %%
data['months since last claim'].nunique()
data['months since last claim'].value_counts()
# Out:
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 23.0    276
# 19.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: months since last claim, dtype: int64

# %%
data['months since last claim'] = data['months since last claim'].fillna('0')
len(data[data['months since last claim'].isna() == True])
# Out:
# 0

# %%
data['response'].nunique()
data['response'].value_counts()
# Out:
# No         8813
# Yes        1466
# Unknown     631
# Name: response, dtype: int64

# %%
data['number of open complaints'].nunique()
data['number of open complaints'].value_counts()
# Out:
# 0.0    8160
# 1.0    1145
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number of open complaints, dtype: int64

# %%
data['number of open complaints'] = data['number of open complaints'].fillna('0.0')
len(data[data['number of open complaints'].isna() == True])
# Out:
# 0

# %%
#¿por qué se ha duplicado el valor?
data['number of open complaints'].nunique()
data['number of open complaints'].value_counts()
# Out:
# 0.0    8160
# 1.0    1145
# 0.0     633
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number of open complaints, dtype: int64

# %%
data.isna().sum()
# Out:
# unnamed: 0                          0
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim             0
# months since policy inception       0
# number of open complaints           0
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# ...

# %%
data['vehicle class'].nunique()
data['vehicle class'].value_counts()
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64

# %%
data['vehicle class'] = data['vehicle class'].fillna('Unknown')
len(data[data['vehicle class'].isna() == True])
# Out:
# 0

# %%
data['vehicle type'].nunique()
data['vehicle type'].value_counts()
# Out:
# A    5428
# Name: vehicle type, dtype: int64

# %%
data['vehicle type'] = data['vehicle type'].fillna('Unknown')
len(data[data['vehicle type'].isna() == True])
# Out:
# 0

# %%
data['vehicle size'].nunique()
data['vehicle size'].value_counts()
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# Name: vehicle size, dtype: int64

# %%
data['vehicle size'] = data['vehicle size'].fillna('Unknown')
len(data[data['vehicle size'].isna() == True])
# Out:
# 0

# %%
data.isna().sum()
# Out:
# unnamed: 0                       0
# customer                         0
# state                            0
# customer lifetime value          0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location code                    0
# marital status                   0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# total claim amount               0
# vehicle class                    0
# vehicle size                     0
# vehicle type                     0
# dtype: int64

# %%
data = data.drop([data.columns[0]], axis=1)
data.head(5)
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender   income  ...  \
# 0        2011-02-18         Employed      M  48029.0  ...
# 1        2011-01-18       Unemployed      F      0.0  ...
# 2        2011-02-10         Employed      M  22139.0  ...
# 3        2011-01-11         Employed      M  49078.0  ...
# 4        2011-01-17    Medical Leave      F  23675.0  ...
#
#   number of open complaints number of policies     policy type        policy  \
# ...

# %%
display(data['coverage'].unique())
display(data['coverage'].value_counts())
data['coverage'].value_counts(dropna=False)
# Out:
# array(['Basic', 'Extended', 'Premium'], dtype=object)
# Basic       6660
# Extended    3265
# Premium      985
# Name: coverage, dtype: int64
# Basic       6660
# Extended    3265
# Premium      985
# Name: coverage, dtype: int64

# %%
# Datetime format - Extract the months from the dataset and store in 
#a separate column. Then filter the data to show only the information 
#for the first quarter , ie. January, February and March. Hint: 
#If data from March does not exist, consider only January and February.

# %%
data['effective to date'] = pd.to_datetime(data['effective to date'], errors ='coerce')
display(data.head(5))
print(data.dtypes)
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender   income  ...  \
# 0        2011-02-18         Employed      M  48029.0  ...
# 1        2011-01-18       Unemployed      F      0.0  ...
# 2        2011-02-10         Employed      M  22139.0  ...
# 3        2011-01-11         Employed      M  49078.0  ...
# 4        2011-01-17    Medical Leave      F  23675.0  ...
#
#   number of open complaints number of policies     policy type        policy  \
# ...

# %%
import datetime

# %%
data['month'] = data['effective to date'].dt.month

# %%
data.head(5)
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender   income  ... number of policies  \
# 0        2011-02-18         Employed      M  48029.0  ...                9.0
# 1        2011-01-18       Unemployed      F      0.0  ...                1.0
# 2        2011-02-10         Employed      M  22139.0  ...                2.0
# 3        2011-01-11         Employed      M  49078.0  ...                2.0
# 4        2011-01-17    Medical Leave      F  23675.0  ...                7.0
#
# ...

# %%
display(data['month'].unique())
display(data['month'].value_counts())
data['month'].value_counts(dropna=False)
# Out:
# array([2, 1])
# 1    5818
# 2    5092
# Name: month, dtype: int64
# 1    5818
# 2    5092
# Name: month, dtype: int64

# %%
data4 = data.copy()

# %%
data4
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877     Unknown              6857.519928  Unknown     Basic
#
#       education effective to date employmentstatus gender   income  ...  \
# ...

# %%
def clean(x):
    if x in [1]:
        return 'January'
    elif x in [2]:
        return 'Febrery'
    
data4['month'] = data4['month'].apply(clean)

# %%
display(data4['month'].unique())
# Out:
# array(['Febrery', 'January'], dtype=object)

# %%
display(data4['month'].unique())
display(data4['month'].value_counts())
data4['month'].value_counts(dropna=False)
# Out:
# array([2, 1])
# 1    5818
# 2    5092
# Name: month, dtype: int64
# 1    5818
# 2    5092
# Name: month, dtype: int64

# %%
data4.head(5)
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender   income  ... number of policies  \
# 0        2011-02-18         Employed      M  48029.0  ...                9.0
# 1        2011-01-18       Unemployed      F      0.0  ...                1.0
# 2        2011-02-10         Employed      M  22139.0  ...                2.0
# 3        2011-01-11         Employed      M  49078.0  ...                2.0
# 4        2011-01-17    Medical Leave      F  23675.0  ...                7.0
#
# ...
